# %% [markdown]
# # 🚀 Setting Up Apache Beam in Google Colab
#
# Now that we are done with the theory, let’s **move to practicals**.
# Before we write our first Beam pipeline, we need a proper setup.
#
# ---
#
# ## 1️⃣ Why Colab for Apache Beam?
#
# - Installing Beam **locally** can be tricky:
#   - Requires Python setup
#   - Managing versions & dependencies
#   - Paths & environment issues
#
# - To avoid these issues, we will use **Google Colab**.
#
# 👉 **What is Colab?**
# - Online Jupyter-like environment provided by Google.
# - Runs Python code on a **Google Virtual Machine**.
# - Provides **RAM + Disk** for execution.
# - No installation needed, just open in browser.
# - Supports saving notebooks in **Google Drive**.
#
# 💡 Think of Colab as an **online Jupyter Notebook** where setup is already handled.
#
# ---
#
# ## 2️⃣ Installing Apache Beam in Colab
#
# In Colab, to run **shell commands** we prefix them with `!`.
# For example, to install Beam:
#
# ```python
# !pip install --quiet apache-beam

# %%
# !pip install apache-beam
# Out:
# Collecting apache-beam
#   Downloading apache_beam-2.68.0-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting crcmod<2.0,>=1.7 (from apache-beam)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ---------------------------------------- 0.0/89.7 kB ? eta -:--:--
#      ------------------ --------------------- 41.0/89.7 kB 1.9 MB/s eta 0:00:01
#      ---------------------------------------- 89.7/89.7 kB 1.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting orjson<4,>=3.9.7 (from apache-beam)
#   Downloading orjson-3.11.3-cp311-cp311-win_amd64.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.0 kB ? eta -:--:--
#      ---------------------------------------- 43.0/43.0 kB ? eta 0:00:00
# Collecting dill<0.3.2,>=0.3.1.1 (from apache-beam)
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ---------------------------------------- 0.0/152.0 kB ? eta -:--:--
#      -------------------------------------- 152.0/152.0 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting fastavro<2,>=0.23.6 (from apache-beam)
#   Downloading fastavro-1.12.0-cp311-cp311-win_amd64.whl.metadata (5.7 kB)
# Collecting fasteners<1.0,>=0.3 (from apache-beam)
#   Downloading fasteners-0.20-py3-none-any.whl.metadata (4.8 kB)
# Collecting grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1 (from apache-beam)
#   Downloading grpcio-1.65.5-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache-beam)
#   Downloading hdfs-2.7.3.tar.gz (43 kB)
#      ---------------------------------------- 0.0/43.5 kB ? eta -:--:--
#      ---------------------------------------- 43.5/43.5 kB ? eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting httplib2<0.23.0,>=0.8 (from apache-beam)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from apache-beam) (4.19.0)
# Collecting jsonpickle<4.0.0,>=3.0.0 (from apache-beam)
#   Downloading jsonpickle-3.4.2-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy<2.3.0,>=1.14.3 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from apache-beam) (2.2.6)
# Collecting objsize<0.8.0,>=0.6.1 (from apache-beam)
#   Downloading objsize-0.7.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging>=22.0 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from apache-beam) (23.1)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache-beam)
#   Downloading pymongo-4.15.1-cp311-cp311-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from apache-beam) (1.22.3)
# Collecting protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<6.0.0.dev0,>=3.20.3 (from apache-beam)
#   Downloading protobuf-5.29.5-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting pydot<2,>=1.2.0 (from apache-beam)
#   Downloading pydot-1.4.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from apache-beam) (2.8.2)
# Requirement already satisfied: pytz>=2018.3 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from apache-beam) (2025.2)
# Collecting redis<6,>=5.0.0 (from apache-beam)
#   Downloading redis-5.3.1-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: regex>=2020.6.8 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from apache-beam) (2025.9.1)
# Collecting requests<3.0.0,>=2.32.4 (from apache-beam)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting sortedcontainers>=2.4.0 (from apache-beam)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions>=3.7.0 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from apache-beam) (4.15.0)
# Collecting zstandard<1,>=0.18.0 (from apache-beam)
#   Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=3.12 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from apache-beam) (6.0.1)
# Collecting beartype<0.22.0,>=0.21.0 (from apache-beam)
#   Downloading beartype-0.21.0-py3-none-any.whl.metadata (33 kB)
# Collecting pyarrow<19.0.0,>=3.0.0 (from apache-beam)
#   Downloading pyarrow-18.1.0-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Collecting pyarrow-hotfix<1 (from apache-beam)
#   Downloading pyarrow_hotfix-0.7-py3-none-any.whl.metadata (3.6 kB)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache-beam)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: six>=1.9.0 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam) (1.16.0)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 (from httplib2<0.23.0,>=0.8->apache-beam)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (0.10.2)
# Collecting protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<6.0.0.dev0,>=3.20.3 (from apache-beam)
#   Downloading protobuf-4.25.8-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache-beam)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting PyJWT>=2.9.0 (from redis<6,>=5.0.0->apache-beam)
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.4->apache-beam) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.4->apache-beam) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.4->apache-beam) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhask\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.4->apache-beam) (2023.7.22)
# Downloading apache_beam-2.68.0-cp311-cp311-win_amd64.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.4/5.6 MB 8.9 MB/s eta 0:00:01
#    ------- -------------------------------- 1.1/5.6 MB 11.6 MB/s eta 0:00:01
#    ------------- -------------------------- 1.8/5.6 MB 13.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.5/5.6 MB 13.3 MB/s eta 0:00:01
#    ------------------------- -------------- 3.6/5.6 MB 15.4 MB/s eta 0:00:01
#    --------------------------------- ------ 4.6/5.6 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------------  5.6/5.6 MB 17.9 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 15.5 MB/s eta 0:00:00
# Downloading beartype-0.21.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------  1.2/1.2 MB 25.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 19.0 MB/s eta 0:00:00
# Downloading fastavro-1.12.0-cp311-cp311-win_amd64.whl (451 kB)
#    ---------------------------------------- 0.0/451.8 kB ? eta -:--:--
#    --------------------------------------- 451.8/451.8 kB 29.4 MB/s eta 0:00:00
# Downloading fasteners-0.20-py3-none-any.whl (18 kB)
# Downloading grpcio-1.65.5-cp311-cp311-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/4.1 MB 33.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.0/4.1 MB 33.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.0/4.1 MB 33.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.0/4.1 MB 33.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.0/4.1 MB 33.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 1
MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  25.1/25.1 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------- 25.1/25.1 MB 25.2 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.7-py3-none-any.whl (7.9 kB)
# Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Downloading pymongo-4.15.1-cp311-cp311-win_amd64.whl (858 kB)
#    ---------------------------------------- 0.0/859.0 kB ? eta -:--:--
#    --------------------------------------- 859.0/859.0 kB 27.4 MB/s eta 0:00:00
# Downloading redis-5.3.1-py3-none-any.whl (272 kB)
#    ---------------------------------------- 0.0/272.8 kB ? eta -:--:--
#    --------------------------------------- 272.8/272.8 kB 16.4 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.7 kB ? eta -:--:--
#    ---------------------------------------- 64.7/64.7 kB 3.4 MB/s eta 0:00:00
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
#    ---------------------------------------- 0.0/506.2 kB ? eta -:--:--
#    --------------------------------------- 506.2/506.2 kB 31.0 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ---------------------------------------- 0.0/331.1 kB ? eta -:--:--
#    --------------------------------------- 331.1/331.1 kB 20.1 MB/s eta 0:00:00
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#    ---------------------------------------- 0.0/113.9 kB ? eta -:--:--
#    ---------------------------------------- 113.9/113.9 kB 6.9 MB/s eta 0:00:00
# Building wheels for collected packages: crcmod, dill, hdfs, docopt
#   Building wheel for crcmod (pyproject.toml): started
#   Building wheel for crcmod (pyproject.toml): finished with status 'done'
#   Created wheel for crcmod: filename=crcmod-1.7-py3-none-any.whl size=18948 sha256=ca60f5675e9bc4c7dc00fd6d6223baf25f70495f027404aecb1941f25c83e30d
#   Stored in directory: c:\users\bhask\appdata\local\pip\cache\wheels\23\94\7a\8cb7d14597e6395ce969933f01aed9ea8fa5f5b4d4c8a61e99
#   Building wheel for dill (pyproject.toml): started
#   Building wheel for dill (pyproject.toml): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78755 sha256=d357b6c22bead974063b4ad7c3be3d0f7616fb2b30389a25d5bc077c8addefd4
#   Stored in directory: c:\users\bhask\appdata\local\pip\cache\wheels\01\60\80\1622338bcecce31a5664ef01c203cc5a7b09f59588d9c07376
#   Building wheel for hdfs (pyproject.toml): started
#   Building wheel for hdfs (pyproject.toml): finished with status 'done'
#   Created wheel for hdfs: filename=hdfs-2.7.3-py3-none-any.whl size=34461 sha256=cfb9a3590cb81a8e76bc9ce8e5a767315cf4de5e718b161a80ac139630535794
#   Stored in directory: c:\users\bhask\appdata\local\pip\cache\wheels\b9\1d\dc\eb0833be25464c359903d356c4204721c6a672c26ff164cdc3
#   Building wheel for docopt (pyproject.toml): started
#   Building wheel for docopt (pyproject.toml): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13858 sha256=1bb1a94ad6f03fa1995d99214d78ae37cb0400c18a480ac173628d0e3fc2b8c5
#   Stored in directory: c:\users\bhask\appdata\local\pip\cache\wheels\1a\b0\8c\4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built crcmod dill hdfs docopt
# Installing collected packages: sortedcontainers, docopt, crcmod, zstandard, requests, pyparsing, PyJWT, pyarrow-hotfix, pyarrow, protobuf, orjson, objsize, jsonpickle, grpcio, fasteners, fastavro, dnspython, dill, beartype, redis, pymongo, pydot, httplib2, hdfs, apache-beam
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.24.3
#     Uninstalling protobuf-4.24.3:
#       Successfully uninstalled protobuf-4.24.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.59.2
#     Uninstalling grpcio-1.59.2:
#       Successfully uninstalled grpcio-1.59.2
#   Attempting uninstall: dill
#     Found existing installation: dill 0.4.0
#     Uninstalling dill-0.4.0:
#       Successfully uninstalled dill-0.4.0
# Successfully installed PyJWT-2.10.1 apache-beam-2.68.0 beartype-0.21.0 crcmod-1.7 dill-0.3.1.1 dnspython-2.8.0 docopt-0.6.2 fastavro-1.12.0 fasteners-0.20 grpcio-1.65.5 hdfs-2.7.3 httplib2-0.22.0 jsonpickle-3.4.2 objsize-0.7.1 orjson-3.11.3 protobuf-4.25.8 pyarrow-18.1.0 pyarrow-hotfix-0.7 pydot-1.4.2 pymongo-4.15.1 pyparsing-3.2.5 redis-5.3.1 requests-2.32.5 sortedcontainers-2.4.0 zstandard-0.25.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mysql-connector-python 8.0.33 requires protobuf<=3.20.3,>=3.11.0, but you have protobuf 4.25.8 which is incompatible.
# pylint 2.17.4 requires dill>=0.3.6; python_version >= "3.11", but you have dill 0.3.1.1 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !mkdir -p data
# Out:
# A subdirectory or file -p already exists.
# Error occurred while processing: -p.
# A subdirectory or file data already exists.
# Error occurred while processing: data.

# %%
# !mkdir data
# Out:
# A subdirectory or file data already exists.

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 96E0-2891
#
#  Directory of c:\Users\bhask\AppData\Local\Programs\Microsoft VS Code
#
# 26-09-2025  18:12    <DIR>          .
# 01-09-2025  16:26    <DIR>          ..
# 26-09-2025  18:12    <DIR>          -p
# 26-09-2025  10:36    <DIR>          appx
# 23-09-2025  12:35    <DIR>          bin
# 18-09-2025  00:07           167,282 chrome_100_percent.pak
# 18-09-2025  00:07           258,304 chrome_200_percent.pak
# 18-09-2025  00:11       197,459,000 Code.exe
# 18-09-2025  00:07               367 Code.VisualElementsManifest.xml
# 18-09-2025  00:10         4,927,032 d3dcompiler_47.dll
# 26-09-2025  18:12    <DIR>          data
# 18-09-2025  00:11         2,882,080 ffmpeg.dll
# 18-09-2025  00:07        10,467,680 icudtl.dat
# 18-09-2025  00:09           515,616 libEGL.dll
# 18-09-2025  00:10         8,061,472 libGLESv2.dll
# 18-09-2025  00:07        15,091,641 LICENSES.chromium.html
# 23-09-2025  12:35    <DIR>          locales
# 23-09-2025  12:35    <DIR>          policies
# 23-09-2025  12:35    <DIR>          resources
# 18-09-2025  00:07         5,836,921 resources.pak
# 18-09-2025  00:07           321,542 snapshot_blob.bin
# 26-09-2025  10:36    <DIR>          tools
# 26-09-2025  10:36         2,199,763 unins000.dat
# 26-09-2025  10:35         3,494,968 unins000.exe
# 26-09-2025  10:36            24,367 unins000.msg
# 18-09-2025  00:07           699,577 v8_context_snapshot.bin
# 18-09-2025  00:10         5,540,912 vk_swiftshader.dll
# 18-09-2025  00:07               106 vk_swiftshader_icd.json
# 18-09-2025  00:10           931,912 vulkan-1.dll
# 26-09-2025  10:36    <DIR>          _
#               19 File(s)    258,880,542 bytes
#               11 Dir(s)  71,416,127,488 bytes free
